# %% [markdown]
# # $2 \times 2$ HRS Multiplier
#
# This is a `9`-qubit circuit.

# %%
from qiskit import *

# %% [markdown]
# ***
#
# First we build a `hrs-multiplier` circuit.

# %%
from qiskit.circuit.library import HRSCumulativeMultiplier

# %%
mult = HRSCumulativeMultiplier(2)  # 2 qubit type
hrs = mult.to_gate()

# %% [markdown]
# `hrs` is 2-qubit HRS Cumulative Multiplier.

# %% [markdown]
# ***
#
# Building the Circuit

# %%
inp = QuantumRegister(4, 'input')
out = QuantumRegister(5, 'output')
cbit = ClassicalRegister(4, 'cbits')
multiplier = QuantumCircuit(inp, out, cbit)

# %%
# taking input

for i in range(4) :
    multiplier.x(inp[i])

# %%
multiplier.draw('mpl')

# %%
# Add Multiplier Block to Circuit

multiplier.barrier()
multiplier.append(hrs,[inp[0],inp[1],inp[2],inp[3],out[0],out[1],out[2],out[3],out[4]])
multiplier.barrier()

# %%
multiplier.draw('mpl')

# %%
# adding measure gates
multiplier.measure(out[0], cbit[0])
multiplier.measure(out[1], cbit[1])
multiplier.measure(out[2], cbit[2])
multiplier.measure(out[3], cbit[3])

# %%
multiplier.draw('mpl')

# %% [markdown]
# ***
#
# After building the circuit, we simulate it.

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(multiplier, simulator).result()

# %%
from qiskit.visualization import plot_histogram

# %%
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# ***
#
# HANOI - NOISY SIMULATION
#
# Simulation-1

# %%
from qiskit.providers.fake_provider import FakeHanoi
from qiskit.providers.aer import AerSimulator

# %%
# simulating the circuit on a fake simulator

hanoi = FakeHanoi()
simulator = AerSimulator.from_backend(hanoi)

# %%
compiled_circuit = transpile(multiplier, simulator)

# %%
# %%time

# result = execute(compiled_circuit, simulator, counts = 1024).result()
result = execute(multiplier, simulator, counts = 1024).result()
# Out:
# CPU times: total: 5.72 s
# Wall time: 1.89 s

# %%
fake_counts = result.get_counts()

# %%
plot_histogram(fake_counts)

# %% [markdown]
# ***
#
# Simulation-2

# %%
# simulating the circuit on a fake simulator

hanoi = FakeHanoi()
simulator = AerSimulator.from_backend(hanoi)

# %%
compiled_circuit = transpile(multiplier, simulator)

# %%
# %%time

# result = execute(compiled_circuit, simulator, counts = 1024).result()
result = execute(multiplier, simulator, counts = 1024).result()
# Out:
# CPU times: total: 5.75 s
# Wall time: 1.87 s

# %%
fake_counts = result.get_counts()

# %%
plot_histogram(fake_counts)

# %% [markdown]
# ***
#
# Simulation-3

# %%
# simulating the circuit on a fake simulator

hanoi = FakeHanoi()
simulator = AerSimulator.from_backend(hanoi)

# %%
compiled_circuit = transpile(multiplier, simulator)

# %%
# %%time

# result = execute(compiled_circuit, simulator, counts = 1024).result()
result = execute(multiplier, simulator, counts = 1024).result()
# Out:
# CPU times: total: 4.22 s
# Wall time: 1.85 s

# %%
fake_counts = result.get_counts()

# %%
plot_histogram(fake_counts)
